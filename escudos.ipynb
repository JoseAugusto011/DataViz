# %%
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt 
import matplotlib.patches as ptc

# %%
#fig, ax = plt.subplots() # cria figura com eixo único

# altura/largura
a = 3; b = 1.6*a

# área de plotagem
fig, ax = plt.subplots(figsize=(b,a))

spa_x = 0.1
spa_y = 0.1
# losango
los_vertices = [(0.35+spa_x,0.0+spa_y), (0.13+spa_x,0.0+spa_y), (0.0+spa_x,0.13+spa_y), (0.11+spa_x,0.24+spa_y)]
los = ptc.Polygon(los_vertices, 
                  closed=True,
                  facecolor='y',
                  edgecolor='k',
                  lw=2)
los_vertices2 = [(0.38+spa_x,0.03+spa_y), (0.38+spa_x,0.25+spa_y), (0.25+spa_x,0.38+spa_y), (0.14+spa_x,0.27+spa_y)]
los2 = ptc.Polygon(los_vertices2, 
                  closed=True,
                  facecolor='y',
                  edgecolor='k',
                  lw=2)
los_vertices3 = [(0.45+spa_x,0.0+spa_y), (0.67+spa_x,0.0+spa_y), (0.80+spa_x,0.13+spa_y), (0.69+spa_x,0.24+spa_y)]
los3 = ptc.Polygon(los_vertices3, 
                  closed=True,
                  facecolor='y',
                  edgecolor='k',
                  lw=2)
los_vertices4 = [(0.42+spa_x,0.03+spa_y), (0.42+spa_x,0.25+spa_y), (0.55+spa_x,0.38+spa_y), (0.66+spa_x,0.27+spa_y)]
los4 = ptc.Polygon(los_vertices4, 
                  closed=True,
                  facecolor='y',
                  edgecolor='k',
                  lw=2)




ax.add_patch(los)
ax.add_patch(los2)
ax.add_patch(los3)
ax.add_patch(los4)

#[(0.25+spa_x,0.43+spa_y), (0.55+spa_x,0,43+spa_y)]

ax.plot([0.25+spa_x , 0.4+spa_x , 0.55+spa_x],[0.43+spa_y , 0.43+spa_y , 0.43+spa_y],'*',
c='y',markersize=20, mec='k')

# %%
#fig, ax = plt.subplots() # cria figura com eixo único

# altura/largura
a = 3; b = 1.6*a

# área de plotagem
fig, ax = plt.subplots(figsize=(b,a))

#rectangulo

rec = ptc.Rectangle(xy=(0,0), 
                    height=1, 
                    width=1,
                    angle=0,
                    facecolor='k',
                    edgecolor='k')

spa_x = 0.0
spa_y = 0.0
tama_linha =4
# losango
los_vertices = [(0.50+spa_x,0.0+spa_y), (0.14+spa_x,0.44+spa_y), 
(0.14+spa_x,0.72+spa_y), (0.86+spa_x,0.72+spa_y), (0.86+spa_x,0.44+spa_y)]
los = ptc.Polygon(los_vertices, 
                  closed=True,
                  facecolor='w',
                  edgecolor='w',
                  lw=1)
los_vertices2 = [(0.44+spa_x,0.14+spa_y), (0.18+spa_x,0.45+spa_y), 
(0.44+spa_x,0.45+spa_y)]
los2 = ptc.Polygon(los_vertices2, 
                  closed=True,
                  facecolor='r',
                  edgecolor='r',
                  lw=1)

los_vertices3 = [(0.56+spa_x,0.14+spa_y), (0.56+spa_x,0.45+spa_y), 
(0.82+spa_x,0.45+spa_y)]
los3 = ptc.Polygon(los_vertices3, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=1)

los_vertices4 = [(0.18+spa_x,0.50+spa_y), (0.18+spa_x,0.68+spa_y), 
(0.82+spa_x,0.68+spa_y), (0.82+spa_x,0.50+spa_y)]
los4 = ptc.Polygon(los_vertices4, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=1)



ax.add_patch(rec)
ax.add_patch(los)
ax.add_patch(los2)
ax.add_patch(los3)
ax.add_patch(los4)

ax.plot([0.78+spa_x , 0.78+spa_x , 0.69+spa_x, 0.69+spa_x , 0.78+spa_x , 0.78+spa_x],
[0.55+spa_y , 0.54+spa_y , 0.54+spa_y, 0.64+spa_y , 0.64+spa_y , 0.63+spa_y],
c='w',linewidth=tama_linha, mec='w')

# ffffffffffffffffffffffffffffff

ax.plot([0.53+spa_x , 0.53+spa_x , 0.60+spa_x, 0.53+spa_x , 0.53+spa_x , 0.62+spa_x],
[0.54+spa_y , 0.59+spa_y , 0.59+spa_y, 0.59+spa_y , 0.64+spa_y , 0.64+spa_y],
c='w',linewidth=tama_linha, mec='w')

# ppppppppppppppppppppppppppppppp

ax.plot([0.37+spa_x , 0.37+spa_x , 0.47+spa_x, 0.47+spa_x , 0.37+spa_x , 0.37+spa_x],
[0.54+spa_y , 0.59+spa_y , 0.59+spa_y, 0.64+spa_y , 0.64+spa_y, 0.59+spa_y ],
c='w',linewidth=tama_linha, mec='w')

# ssssssssssssssssssssssssssssss

ax.plot([0.22+spa_x , 0.31+spa_x , 0.31+spa_x, 0.22+spa_x , 0.22+spa_x , 0.31+spa_x],
[0.54+spa_y , 0.54+spa_y , 0.59+spa_y , 0.59+spa_y, 0.64+spa_y , 0.64+spa_y],
c='w',linewidth=tama_linha, mec='w')


#[(0.25+spa_x,0.43+spa_y), (0.55+spa_x,0,43+spa_y)]

#ax.plot([0.25+spa_x , 0.4+spa_x , 0.55+spa_x],[0.43+spa_y , 0.43+spa_y , 0.43+spa_y],'*',
#c='y',markersize=20, mec='k')

ax.plot([0.24+spa_x , 0.76+spa_x ],[0.79+spa_y , 0.79+spa_y],'*',
c='y',markersize=20, mec='k')

ax.plot([0.41+spa_x , 0.59+spa_x , 0.50+spa_x],[0.79+spa_y , 0.79+spa_y , 0.91+spa_y],'*',
c='r',markersize=20, mec='k')

# %%
# altura/largura
a = 3
b = 1.6 * a

# área de plotagem
fig, ax = plt.subplots(figsize=(b, a))

# retângulo
rec = ptc.Rectangle(xy=(0, 0),
                    height=1,
                    width=1,
                    angle=0,
                    facecolor='k',
                    edgecolor='k')

spa_x = 0.0
spa_y = 0.0
tama_linha = 4

# losango
los_vertices = [(0.49 + spa_x, 0.0 + spa_y), (0.86 + spa_x, 0.56 + spa_y),
                (0.86 + spa_x, 0.79 + spa_y), (0.12 + spa_x, 0.79 + spa_y), (0.12 + spa_x, 0.56 + spa_y)]
los = ptc.Polygon(los_vertices,
                  closed=True,
                  facecolor='b',
                  edgecolor='b',
                  lw=1)

los_vertices5 = [(0.49 + spa_x, 0.04 + spa_y), (0.84 + spa_x, 0.57 + spa_y),
                 (0.14 + spa_x, 0.57 + spa_y)]
los5 = ptc.Polygon(los_vertices5,
                   closed=True,
                   facecolor='w',
                   edgecolor='w',
                   lw=1)

los_vertices2 = [(0.48 + spa_x, 0.10 + spa_y), (0.48 + spa_x, 0.55 + spa_y),
                 (0.18 + spa_x, 0.55 + spa_y)]
los2 = ptc.Polygon(los_vertices2,
                   closed=True,
                   facecolor='b',
                   edgecolor='b',
                   lw=1)

los_vertices3 = [(0.50 + spa_x, 0.10 + spa_y), (0.80 + spa_x, 0.55 + spa_y),
                 (0.50 + spa_x, 0.55 + spa_y)]
los3 = ptc.Polygon(los_vertices3,
                   closed=True,
                   facecolor='r',
                   edgecolor='r',
                   lw=1)

los_vertices4 = [(0.14 + spa_x, 0.59 + spa_y), (0.14 + spa_x, 0.76 + spa_y),
                 (0.84 + spa_x, 0.76 + spa_y), (0.84 + spa_x, 0.59 + spa_y)]
los4 = ptc.Polygon(los_vertices4,
                   closed=True,
                   facecolor='w',
                   edgecolor='w',
                   lw=1)

# Adicionando os patches ao gráfico
ax.add_patch(rec)
ax.add_patch(los)
ax.add_patch(los5)
ax.add_patch(los2)
ax.add_patch(los3)
ax.add_patch(los4)

# Adicionando o nome do clube
club_name = 'Fortaleza'
x_pos = 0.5  # Posição x do texto
y_pos = 0.6  # Posição y do texto
font_size = 30
font_family = 'Eras Medium ITC'

# Adicionando o texto com a função text()
ax.text(x_pos, y_pos, club_name, fontsize=font_size, family=font_family, color='b', ha='center')

plt.show()

# %%
#fig, ax = plt.subplots() # cria figura com eixo único

# altura/largura
a = 3; b = 1.6*a

# área de plotagem
fig, ax = plt.subplots(figsize=(b,a))

#rectangulo

rec = ptc.Rectangle(xy=(0,0), 
                    height=1, 
                    width=1,
                    angle=0,
                    facecolor='k',
                    edgecolor='k')

spa_x = 0.0
spa_y = 0.0
tama_linha =4
# losango
los_vertices = [(0.50+spa_x,0.05+spa_y), (0.52+spa_x,0.06+spa_y),(0.55+spa_x,0.08+spa_y), 
(0.60+spa_x,0.12+spa_y), (0.63+spa_x,0.14+spa_y), (0.69+spa_x,0.19+spa_y),
(0.73+spa_x,0.24+spa_y), (0.77+spa_x,0.29+spa_y), (0.79+spa_x,0.32+spa_y),
(0.82+spa_x,0.39+spa_y), (0.86+spa_x,0.50+spa_y), (0.87+spa_x,0.59+spa_y),
(0.88+spa_x,0.61+spa_y), (0.88+spa_x,0.83+spa_y), (0.83+spa_x,0.84+spa_y),
(0.72+spa_x,0.87+spa_y), (0.65+spa_x,0.91+spa_y), (0.58+spa_x,0.93+spa_y),
(0.50+spa_x,0.95+spa_y),  (1-0.58+spa_x,0.93+spa_y),(1-0.65+spa_x,0.91+spa_y),
(1-0.72+spa_x,0.87+spa_y), (1-0.83+spa_x,0.84+spa_y), (1-0.88+spa_x,0.83+spa_y),
(1-0.88+spa_x,0.61+spa_y), (1-0.87+spa_x,0.59+spa_y), (1-0.86+spa_x,0.50+spa_y),
(1-0.82+spa_x,0.39+spa_y), (1-0.79+spa_x,0.32+spa_y), (1-0.77+spa_x,0.29+spa_y),
(1-0.73+spa_x,0.24+spa_y), (1-0.69+spa_x,0.19+spa_y), (1-0.63+spa_x,0.14+spa_y),
(1-0.60+spa_x,0.12+spa_y), (1-0.55+spa_x,0.08+spa_y), (1-0.52+spa_x,0.06+spa_y)]
los = ptc.Polygon(los_vertices, 
                  closed=True,
                  facecolor='w',
                  edgecolor='w',
                  lw=1)

# losango
los_vertices2 = [(0.50+spa_x,0.10+0.05+spa_y), 
(-0.05+0.60+spa_x,0.05+0.12+spa_y), (-0.05+0.63+spa_x,0.05+0.14+spa_y), 
(-0.05+0.69+spa_x,0.05+0.19+spa_y), (-0.05+0.73+spa_x,0.05+0.24+spa_y), 
(-0.05+0.77+spa_x,0.05+0.29+spa_y), (-0.05+0.79+spa_x,0.05+0.32+spa_y),
(-0.05+0.82+spa_x,0.05+0.39+spa_y), (-0.05+0.86+spa_x,0.50+spa_y), 
(-0.05+0.87+spa_x,-0.05+0.59+spa_y), (-0.05+0.88+spa_x,-0.05+0.61+spa_y), 
(-0.05+0.88+spa_x,-0.05+0.83+spa_y), (-0.05+0.83+spa_x,-0.05+0.84+spa_y),
(-0.05+0.72+spa_x,-0.05+0.87+spa_y), (-0.05+0.65+spa_x,-0.05+0.91+spa_y), 
(-0.05+0.58+spa_x,-0.05+0.93+spa_y), (0.50+spa_x,-0.07+0.95+spa_y),  
(0.05+1-0.58+spa_x,-0.05+0.93+spa_y),(0.05+1-0.65+spa_x,-0.05+0.91+spa_y),
(0.05+1-0.72+spa_x,-0.05+0.87+spa_y), (0.05+1-0.83+spa_x,-0.05+0.84+spa_y), 
(0.05+1-0.88+spa_x,-0.05+0.83+spa_y), (0.05+1-0.88+spa_x,-0.05+0.61+spa_y),
(0.05+1-0.87+spa_x,-0.05+0.59+spa_y), (0.05+1-0.86+spa_x,0.50+spa_y),
(0.05+1-0.82+spa_x,0.05+0.39+spa_y), (0.05+1-0.79+spa_x,0.05+0.32+spa_y), 
(0.05+1-0.77+spa_x,0.05+0.29+spa_y), (0.05+1-0.73+spa_x,0.05+0.24+spa_y), 
(0.05+1-0.69+spa_x,0.05+0.19+spa_y), (0.05+1-0.63+spa_x,0.05+0.14+spa_y),
(0.05+1-0.60+spa_x,0.05+0.12+spa_y),]
los2 = ptc.Polygon(los_vertices2, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=1)


ax.add_patch(rec)
ax.add_patch(los)
ax.add_patch(los2)

ax.plot([0.50+spa_x],[0.54+spa_y],'*',
c='w',markersize=80, mec='w')

# %%
#fig, ax = plt.subplots() # cria figura com eixo único

# altura/largura
a = 3; b = 1.6*a

# área de plotagem
fig, ax = plt.subplots(figsize=(b,a))


spa_x = 0.0
spa_y = 0.0
tama_linha =4
'''# losango
los_vertices = [(0.50+spa_x,0.0+spa_y), (0.58+spa_x,0.04+spa_y),(0.60+spa_x,0.06+spa_y), 
(0.64+spa_x,0.08+spa_y), (0.68+spa_x,0.11+spa_y), (0.75+spa_x,0.18+spa_y),
(0.80+spa_x,0.26+spa_y), (0.83+spa_x,0.31+spa_y), (0.86+spa_x,0.39+spa_y),
(0.88+spa_x,0.50+spa_y), (0.89+spa_x,0.57+spa_y), (0.89+spa_x,0.99+spa_y),
(1-0.89+spa_x,0.99+spa_y), (1-0.89+spa_x,0.57+spa_y), (1-0.88+spa_x,0.50+spa_y),
(1-0.86+spa_x,0.39+spa_y), (1-0.83+spa_x,0.31+spa_y), (1-0.80+spa_x,0.26+spa_y),
(1-0.75+spa_x,0.18+spa_y), (1-0.68+spa_x,0.11+spa_y), (1-0.64+spa_x,0.08+spa_y),
(1-0.60+spa_x,0.06+spa_y), (1-0.58+spa_x,0.04+spa_y),
]
los = ptc.Polygon(los_vertices, 
                  closed=True,
                  facecolor='r',
                  edgecolor='k',
                  lw=4)'''



rec_vertices = [(0.15+spa_x,0.66+spa_y), (0.15+spa_x,0.95+spa_y),(0.48+spa_x,0.95+spa_y), 
(0.48+spa_x,0.66+spa_y)]

rec = ptc.Polygon(rec_vertices, 
                  closed=True,
                  facecolor='r',
                  edgecolor='k',
                  lw=4)

# losango
los_vertices = [(0.50+spa_x,0.02+spa_y), (-0.02+0.58+spa_x,0.02+0.04+spa_y),
(-0.02+0.60+spa_x,0.02+0.06+spa_y), (-0.02+0.64+spa_x,0.02+0.08+spa_y), 
(-0.02+0.68+spa_x,0.02+0.11+spa_y), (-0.02+0.75+spa_x,0.02+0.18+spa_y),
(-0.02+0.80+spa_x,0.02+0.26+spa_y), (-0.02+0.83+spa_x,0.02+0.31+spa_y), 
(-0.02+0.86+spa_x,0.02+0.39+spa_y), (-0.02+0.88+spa_x,0.50+spa_y), 
(-0.02+0.89+spa_x,-0.02+0.57+spa_y), (-0.02+0.89+spa_x,-0.02+0.99+spa_y),
(0.02+1-0.89+spa_x,-0.02+0.99+spa_y), (0.02+1-0.89+spa_x,-0.02+0.57+spa_y), 
(0.02+1-0.88+spa_x,0.50+spa_y), (0.02+1-0.86+spa_x,0.02+0.39+spa_y), 
(0.02+1-0.83+spa_x,0.02+0.31+spa_y), (0.02+1-0.80+spa_x,0.02+0.26+spa_y),
(0.02+1-0.75+spa_x,0.02+0.18+spa_y), (0.02+1-0.68+spa_x,0.02+0.11+spa_y), 
(0.02+1-0.64+spa_x,0.02+0.08+spa_y),
(0.02+1-0.60+spa_x,0.02+0.06+spa_y), (0.02+1-0.58+spa_x,0.02+0.04+spa_y),
]
los = ptc.Polygon(los_vertices, 
                  closed=True,
                  facecolor='r',
                  edgecolor='k',
                  lw=6,)

rec_vertices2 = [(0.87+spa_x,0.88+spa_y), (0.87+spa_x,0.98+spa_y),(0.13+spa_x,0.98+spa_y), 
 (0.13+spa_x,0.75+spa_y), (0.23+spa_x,0.75+spa_y) ,(0.23+spa_x,0.88+spa_y)]

rec2 = ptc.Polygon(rec_vertices2, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=0)

rec_vertices3 = [(0.13+spa_x,0.63+spa_y), (0.13+spa_x,0.75+spa_y),(0.87+spa_x,0.75+spa_y), 
(0.87+spa_x,0.63+spa_y)]

rec3 = ptc.Polygon(rec_vertices3, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=0)

rec_vertices4 = [(0.13+spa_x,0.50+spa_y), (0.16+spa_x,0.39+spa_y),(0.83+spa_x,0.39+spa_y), 
(0.86+spa_x,0.50+spa_y)]

rec4 = ptc.Polygon(rec_vertices4, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=0)

rec_vertices5 = [(0.31+spa_x,0.14+spa_y), (0.69+spa_x,0.14+spa_y),(0.78+spa_x,0.26+spa_y), 
(0.22+spa_x,0.26+spa_y)]

rec5 = ptc.Polygon(rec_vertices5, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=0)



ax.add_patch(los)
ax.add_patch(rec2)
ax.add_patch(rec3)
ax.add_patch(rec4)
ax.add_patch(rec5)

ax.add_patch(rec)

ax.plot([0.34+spa_x, 0.34+spa_x, 0.41+spa_x  , 0.41+spa_x , 
 0.41+spa_x ,0.41+spa_x, 0.34+spa_x, 0.34+spa_x, 0.44+spa_x, 0.44+spa_x ],
[0.69+spa_y, 0.79+spa_y, 0.78+spa_y  , 0.77+spa_y ,  
0.79+spa_y, 0.78+spa_y, 0.79+spa_y, 0.88+spa_y, 0.88+spa_y, 0.86+spa_y],
c='w',linewidth=tama_linha, mec='k')

ax.plot([0.43+spa_x, 0.40+spa_x, 0.33+spa_x  , 0.27+spa_x , 
 0.27+spa_x ,0.27+spa_x, 0.35+spa_x, 0.39+spa_x, 0.33+spa_x],
[0.70+spa_y, 0.69+spa_y, 0.78+spa_y  , 0.78+spa_y ,  
0.69+spa_y, 0.92+spa_y, 0.92+spa_y, 0.87+spa_y, 0.78+spa_y],
c='w',linewidth=tama_linha, mec='k')

ax.plot([0.29+spa_x, 0.22+spa_x, 0.20+spa_x  , 0.22+spa_x , 0.30+spa_x],
[0.73+spa_y, 0.75+spa_y, 0.81+spa_y  , 0.87+spa_y , 0.90+spa_y],
c='w',linewidth=tama_linha, mec='k')

# %%
# altura/largura
a = 3
b = 1.6 * a

# área de plotagem
fig, ax = plt.subplots(figsize=(b, a))

# rectangulo
rec = ptc.Rectangle(xy=(0, 0),
                    height=1,
                    width=1,
                    angle=0,
                    facecolor='k',
                    edgecolor='k')

spa_x = 0.0
spa_y = 0.0
tama_linha = 4

# losango
los_vertices = [(0.50 + spa_x, 1 - 0.0 + spa_y), (0.52 + spa_x, 1 - 0.03 + spa_y), (0.61 + spa_x, 1 - 0.11 + spa_y),
                (0.70 + spa_x, 1 - 0.15 + spa_y), (0.73 + spa_x, 1 - 0.16 + spa_y), (0.82 + spa_x, 1 - 0.17 + spa_y),
                (0.92 + spa_x, 1 - 0.16 + spa_y), (0.92 + spa_x, 1 - 0.27 + spa_y), (0.91 + spa_x, 1 - 0.34 + spa_y),
                (0.88 + spa_x, 1 - 0.49 + spa_y), (0.87 + spa_x, 1 - 0.50 + spa_y), (0.81 + spa_x, 1 - 0.65 + spa_y),
                (0.76 + spa_x, 1 - 0.73 + spa_y), (0.73 + spa_x, 1 - 0.77 + spa_y), (0.57 + spa_x, 1 - 0.93 + spa_y),
                (0.50 + spa_x, 1 - 0.98 + spa_y), (1 - 0.57 + spa_x, 1 - 0.93 + spa_y),
                (1 - 0.73 + spa_x, 1 - 0.77 + spa_y), (1 - 0.76 + spa_x, 1 - 0.73 + spa_y),
                (1 - 0.81 + spa_x, 1 - 0.65 + spa_y), (1 - 0.87 + spa_x, 1 - 0.50 + spa_y),
                (1 - 0.88 + spa_x, 1 - 0.49 + spa_y), (1 - 0.91 + spa_x, 1 - 0.34 + spa_y),
                (1 - 0.92 + spa_x, 1 - 0.27 + spa_y), (1 - 0.92 + spa_x, 1 - 0.16 + spa_y),
                (1 - 0.82 + spa_x, 1 - 0.17 + spa_y), (1 - 0.73 + spa_x, 1 - 0.16 + spa_y),
                (1 - 0.70 + spa_x, 1 - 0.15 + spa_y), (1 - 0.61 + spa_x, 1 - 0.11 + spa_y),
                (1 - 0.52 + spa_x, 1 - 0.03 + spa_y)]


grenar_color = (135/255,10/255,40/255)  # RGB values for a shade of red


los = ptc.Polygon(los_vertices,
                  closed=True,
                  facecolor='w',
                  edgecolor=grenar_color,  # Adjusted color here
                  lw=1)

# losango
los_vertices2 = [(0.50 + spa_x, 1 - (0.07 + 0.0) + spa_y), (0.52 + spa_x, 1 - (0.06 + 0.03) + spa_y),
                 (0.61 + spa_x, 1 - (0.05 + 0.11) + spa_y), (0.70 + spa_x, 1 - (0.05 + 0.15) + spa_y),
                 (0.73 + spa_x, 1 - (0.05 + 0.16) + spa_y), (0.82 + spa_x, 1 - (0.05 + 0.17) + spa_y),
                 (-0.05 + 0.92 + spa_x, 1 - (0.05 + 0.16) + spa_y), (-0.05 + 0.92 + spa_x, 1 - 0.27 + spa_y),
                 (-0.05 + 0.91 + spa_x, 1 - 0.34 + spa_y),

                 (0.83 + spa_x, 1 - 0.47 + spa_y), (1 - 0.83 + spa_x, 1 - 0.47 + spa_y),

                 (0.05 + 1 - 0.91 + spa_x, 1 - 0.34 + spa_y), (0.05 + 1 - 0.92 + spa_x, 1 - 0.27 + spa_y),
                 (0.05 + 1 - 0.92 + spa_x, 1 - (0.05 + 0.16) + spa_y), (1 - 0.82 + spa_x, 1 - (0.05 + 0.17) + spa_y),
                 (1 - 0.73 + spa_x, 1 - (0.05 + 0.16) + spa_y), (1 - 0.70 + spa_x, 1 - (0.05 + 0.15) + spa_y),
                 (1 - 0.61 + spa_x, 1 - (0.05 + 0.11) + spa_y), (1 - 0.52 + spa_x, 1 - (0.06 + 0.03) + spa_y)]
los2 = ptc.Polygon(los_vertices2,
                   closed=True,
                   facecolor=grenar_color,  # Adjusted color here
                   edgecolor='k',
                   lw=0)

los_vertices3 = [(0.82 + spa_x, 1 - 0.51 + spa_y), (-0.05 + 0.81 + spa_x, 1 - 0.65 + spa_y),
                 (-0.05 + 0.76 + spa_x, 1 - 0.73 + spa_y), (-0.05 + 0.73 + spa_x, 1 - 0.77 + spa_y),
                 (0.57 + spa_x, 1 - (-0.06 + 0.93) + spa_y), (0.50 + spa_x, 1 - (-0.06 + 0.98) + spa_y),
                 (1 - 0.57 + spa_x, 1 - (-0.06 + 0.93) + spa_y), (0.05 + 1 - 0.73 + spa_x, 1 - 0.77 + spa_y),
                 (0.05 + 1 - 0.76 + spa_x, 1 - 0.73 + spa_y), (0.05 + 1 - 0.81 + spa_x, 1 - 0.65 + spa_y),
                 (1 - 0.82 + spa_x, 1 - 0.51 + spa_y)]
los3 = ptc.Polygon(los_vertices3,
                   closed=True,
                   facecolor='g',
                   edgecolor='k',
                   lw=0)

ax.add_patch(rec)
ax.add_patch(los)
ax.add_patch(los2)
ax.add_patch(los3)

# ffffffffffffffffffff
ax.plot([0.55 + spa_x, 0.45 + spa_x, 0.41 + spa_x, 0.45 + spa_x,
         0.45 + spa_x, 0.53 + spa_x, 0.53 + spa_x, 0.53 + spa_x, 0.45 + spa_x, 0.45 + spa_x,
         0.41 + spa_x, 0.51 + spa_x, 0.56 + spa_x, 0.62 + spa_x, 0.56 + spa_x],

        [0.23 + spa_y, 0.29 + spa_y, 0.26 + spa_y, 0.29 + spa_y,
         0.57 + spa_y, 0.57 + spa_y, 0.46 + spa_y, 0.57 + spa_y, 0.57 + spa_y, 0.77 + spa_y,
         0.77 + spa_y, 0.77 + spa_y, 0.79 + spa_y, 0.75 + spa_y, 0.69 + spa_y],
        c='w', linewidth=tama_linha, mec='k')

# f2f22f2f2f2f222f2f22f2f2f
ax.plot([0.43 + spa_x, 0.39 + spa_x, 0.34 + spa_x, 0.37 + spa_x,
         0.37 + spa_x, 0.56 + spa_x, 0.37 + spa_x, 0.37 + spa_x, 0.34 + spa_x, 0.50 + spa_x,
         0.65 + spa_x, 0.62 + spa_x, 0.59 + spa_x],

        [0.23 + spa_y, 0.30 + spa_y, 0.32 + spa_y, 0.42 + spa_y,
         0.50 + spa_y, 0.51 + spa_y, 0.50 + spa_y, 0.67 + spa_y, 0.68 + spa_y, 0.70 + spa_y,
         0.68 + spa_y, 0.67 + spa_y, 0.59 + spa_y],
        c='w', linewidth=tama_linha, mec='k')

# cccccccccccccccccccccccc
ax.plot([0.73 + spa_x, 0.66 + spa_x, 0.46 + spa_x, 0.36 + spa_x,
         0.25 + spa_x, 0.25 + spa_x, 0.35 + spa_x, 0.42 + spa_x, 0.57 + spa_x, 0.69 + spa_x,
         0.66 + spa_x, 0.67 + spa_x, 0.72 + spa_x],

        [0.45 + spa_y, 0.41 + spa_y, 0.37 + spa_y, 0.38 + spa_y,
         0.48 + spa_y, 0.52 + spa_y, 0.61 + spa_y, 0.63 + spa_y, 0.64 + spa_y, 0.61 + spa_y,
         0.61 + spa_y, 0.55 + spa_y, 0.55 + spa_y],
        c='w', linewidth=tama_linha, mec='k')

plt.show()

# %%
#fig, ax = plt.subplots() # cria figura com eixo único

# altura/largura
a = 3; b = 1.6*a

# área de plotagem
fig, ax = plt.subplots(figsize=(b,a))

spa_x = 0.0
spa_y = 0.0
tama_linha =10

# losango
los_vertices = [(0.86+spa_x,1-0.0+spa_y), (0.14+spa_x,1-0.59+spa_y)
,(0.14+spa_x,1-0.73+spa_y),(0.86+spa_x,1-0.13+spa_y)]
los = ptc.Polygon(los_vertices, 
                  closed=True,
                  facecolor='r',
                  edgecolor='w',
                  lw=0)

# losango
los_vertices2 = [(0.86+spa_x,1-0.17+spa_y), (0.15+spa_x,1-0.76+spa_y)
,(0.23+spa_x,1-0.82+spa_y),(0.86+spa_x,1-0.30+spa_y)]
los2 = ptc.Polygon(los_vertices2, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=0)

# losango
los_vertices3 = [(0.78+spa_x,1-0.40+spa_y), (0.25+spa_x,1-0.84+spa_y)
,(0.33+spa_x,1-0.90+spa_y),(0.78+spa_x,1-0.53+spa_y)]
los3 = ptc.Polygon(los_vertices3, 
                  closed=True,
                  facecolor='r',
                  edgecolor='w',
                  lw=0)

# losango
los_vertices4 = [(0.71+spa_x,1-0.62+spa_y), (0.35+spa_x,1-0.92+spa_y)
,(0.43+spa_x,1-0.99+spa_y),(0.71+spa_x,1-0.76+spa_y)]
los4 = ptc.Polygon(los_vertices4, 
                  closed=True,
                  facecolor='k',
                  edgecolor='k',
                  lw=0)

ax.add_patch(los)
ax.add_patch(los2)
ax.add_patch(los3)
ax.add_patch(los4)

ax.plot([0.21+spa_x, 0.16+spa_x, 0.16+spa_x  , 0.26+spa_x , 
0.26+spa_x ,0.26+spa_x, 0.26+spa_x, 0.32+spa_x, 0.32+spa_x, 
0.29+spa_x, 0.32+spa_x ,0.32+spa_x, 0.38+spa_x, 0.38+spa_x, 
0.38+spa_x, 0.38+spa_x ,0.45+spa_x, 0.45+spa_x, 0.41+spa_x
],

[1-0.15+spa_y, 1-0.19+spa_y, 1-0.34+spa_y  , 1-0.29+spa_y ,  
1-0.16+spa_y, 1-0.34+spa_y, 1-0.29+spa_y, 1-0.24+spa_y, 1-0.16+spa_y,
1-0.14+spa_y, 1-0.16+spa_y, 1-0.34+spa_y, 1-0.29+spa_y, 1-0.18+spa_y, 
1-0.34+spa_y, 1-0.29+spa_y, 1-0.22+spa_y, 1-0.15+spa_y, 1-0.15+spa_y
],
c='k',linewidth=tama_linha, mec='k')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as ptc
import numpy as np

# Altura/largura
a = 3
b = 3

# Área de plotagem
fig, ax = plt.subplots(figsize=(b, a))

spa_x = 0.0
spa_y = 0.0
tama_linha = 10

cir = ptc.Circle(xy=(0.5, 0.5),
                 radius=0.49,
                 facecolor='g',
                 edgecolor='w',
                 lw=1)

cir2 = ptc.Circle(xy=(0.50, 0.5),
                  radius=0.47,
                  facecolor='g',
                  edgecolor='w',
                  lw=1)

cir3 = ptc.Circle(xy=(0.5, 0.65),
                  radius=0.23,
                  facecolor='g',
                  edgecolor='w',
                  lw=1)

cir4 = ptc.Circle(xy=(0.5, 0.65),
                  radius=0.21,
                  facecolor='w',
                  edgecolor='w',
                  lw=0)

ax.add_patch(cir)
ax.add_patch(cir2)
ax.add_patch(cir3)
ax.add_patch(cir4)

# # Adicionando o texto "PALMEIRAS" ao círculo
# # Calculando a posição ideal para o texto
# angle = np.linspace(0, 2 * np.pi, 100)
# x_circle = 0.4 +  0.2*np.cos(angle)  # Raio do círculo interno é 0.23
# y_circle = 0.4 + 1.4 * 0.25 * np.sin(angle)  # Fator de escala ajustado para 0.8

# # Encontrando o ponto central do círculo
# x_center = ax.get_xlim()[0] + (ax.get_xlim()[1] - ax.get_xlim()[0]) / 2
# y_center = ax.get_ylim()[0] + (ax.get_ylim()[1] - ax.get_ylim()[0]) / 2

# # Adicionando o texto ao gráfico
# for i in range(0, len(x_circle) - 10, 10):
#     ax.text(y_circle[len(y_circle) - 1 - (i + 10)] + 0.1, x_circle[len(x_circle) - 1 - (i + 10)] - 0.05,
#             "PALMEIRAS"[i % len("PALMEIRAS")], color='k', fontsize=16, ha='center', va='center')





# Adicionando o texto "PALMEIRAS" ao círculo usando a função text e mudando a posição do texto de acordo com o ângulo de uma parabola


plt.show()

# %%
from PIL import Image

img = Image.open('AnalisePersonalizada.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=835x197>
